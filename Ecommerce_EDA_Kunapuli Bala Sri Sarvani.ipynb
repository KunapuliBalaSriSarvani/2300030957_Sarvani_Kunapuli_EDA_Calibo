# %% [markdown]
# # E-Commerce Data Analysis & Data Quality Assessment
#
# ## Student EDA Project
#
# **Objective:**
# Perform statistical analysis, data cleaning, validation, outlier detection, and exploratory data analysis on a messy e-commerce dataset using **Pandas, Matplotlib, and Seaborn**.
#
# ## Analysis Workflow
#
# **Messy Dataset → Initial Data Audit → Data Cleaning → Validation → Outlier Analysis → Consistency Check → Clean Dataset → EDA → Business Insights**
#
# ---
#
# ## Dataset
# `messy_ecommerce_15000_student_practice.csv`
#
# ## Tools Used
# - Python
# - Pandas
# - NumPy
# - Matplotlib
# - Seaborn
#
# ## Main Areas Covered
# - Numerical Analysis
# - Categorical Analysis
# - Missing Values
# - Duplicate Records
# - Categorical Consistency
# - Outlier Detection
# - IQR Analysis
# - Data Consistency Validation
# - Univariate Analysis
# - Bivariate Analysis
# - Multivariate Analysis
# - Correlation Analysis
# - Business Insights

# %% [markdown]
# ## 1. Import Required Libraries
#
# The required Python libraries are imported for data manipulation, statistical analysis, visualization, and numerical calculations.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Display settings
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 100)

# Seaborn appearance
sns.set_theme(style="whitegrid")

print("Libraries imported successfully.")
# Out:
# Libraries imported successfully.

# %% [markdown]
# ## 2. Load the Messy Dataset
#
# The original dataset is loaded without modifying it.
#
# All cleaning operations will be performed on a separate copy so that the original messy dataset remains unchanged.

# %%
import os

print("Current folder:")
print(os.getcwd())

print("\nFiles in this folder:")
print(os.listdir())
# Out:
# Current folder:
# c:\Users\srikr\OneDrive\Desktop\calibo
#
# Files in this folder:
# ['2300030957_Ecommerce_EDA', 'All_8_House_Price_Visualizations.png', 'Assignment.ipynb', 'covid data analysis note.ipynb', 'Data visualisation on messy ecommerce dataset.ipynb', 'ecommerce visualisation note.ipynb', 'Ecommerce_Analysis_Dashboard.png', 'Ecommerce_EDA_Kunapuli Bala Sri Sarvani.ipynb', 'Ecommerce_Sales_Data.csv', 'Houseprice.ipynb', 'house_prices_500.csv', 'MESSY E-COMMERCE DATASET - DATA INSPECTION.ipynb', 'messy_ecommerce_15000_student_practice.csv', 'numpy_basics(mndy).ipynb', 'pandas.ipynb', 'pandas1.ipynb', 'Student Performance Analysis.ipynb']
